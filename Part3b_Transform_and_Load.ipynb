# %% [markdown]
# # Transform and Load
#
# For part 3 of the project you will be practicing applying an E.T.L process on your previously downloaded movie data. Specifically, you will prepare the TMDB API data and the Genres data from the title basics file for your SQL Database.

# %% [markdown]
# ## Imports/Settings

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import os, json
import pymysql
import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database

# %% [markdown]
# ## SQL Connection

# %%
#create connection string using credentions
import json
with open('/Users/jeffrey/.secret/mysql.json') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['username', 'password'])

# %%
connection = f"mysql+pymysql://{login['username']}:{login['password']}@localhost/IMDB"

engine = create_engine(connection)

# %%
conn = engine.connect()

# %%
## Check for database
if database_exists(connection):
    print("It Exists!")
else:
    create_database(connection)
    print("New Database Created.")
# Out:
# It Exists!

# %% [markdown]
# ### Test: show tables

# %%
#Show tables: preview
q = '''SHOW TABLES;'''
pd.read_sql(q, conn)
# Out:
#   Tables_in_imdb
# 0         genres
# 1        ratings
# 2   title_basics
# 3   title_genres
# 4      tmdb_data

# %% [markdown]
# ## Load Data // Inspect

# %%
df = pd.read_csv('Data/FINAL_title_basics.csv')
df.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
# 3                          The Naked Monster        0     2005.0      NaN
# 4                       Crime and Punishment        0     2002.0      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86979 entries, 0 to 86978
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          86979 non-null  object
#  1   titleType       86979 non-null  object
#  2   primaryTitle    86979 non-null  object
#  3   originalTitle   86979 non-null  object
#  4   isAdult         86979 non-null  int64
#  5   startYear       86979 non-null  float64
#  6   endYear         0 non-null      float64
#  7   runtimeMinutes  86979 non-null  int64
#  8   genres          86979 non-null  object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 6.0+ MB

# %% [markdown]
# # Transformations

# %% [markdown]
# ## Genre

# %%
#General view of Genre Values
df['genres'].value_counts()
# Out:
# Drama                        17085
# Comedy                        7148
# Horror                        4071
# Comedy,Drama                  4000
# Drama,Romance                 2623
#                              ...
# Music,Mystery,Romance            1
# History,Horror,Mystery           1
# Crime,Music,Mystery              1
# Crime,Fantasy,Romance            1
# Biography,Fantasy,Musical        1
# Name: genres, Length: 854, dtype: int64

# %% [markdown]
# ### Generating List of Unique Genres

# %%
#Create new Column: genre_split from genre feature
df['genre_split'] = df['genres'].str.split(',')
df.head(15)
# Out:
#        tconst titleType                                       primaryTitle  \
# 0   tt0035423     movie                                     Kate & Leopold
# 1   tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2   tt0069049     movie                         The Other Side of the Wind
# 3   tt0088751     movie                                  The Naked Monster
# 4   tt0096056     movie                               Crime and Punishment
# 5   tt0100275     movie                           The Wandering Soap Opera
# 6   tt0103340     movie                    Life for Life: Maximilian Kolbe
# 7   tt0108549     movie                         West from North Goes South
# 8   tt0113026     movie                                    The Fantasticks
# 9   tt0113092     movie                                      For the Cause
# 10  tt0114447     movie                                   The Silent Force
# 11  tt0115937     movie                                        Consequence
# 12  tt0116391     movie                                               Gang
# 13  tt0116628     movie                                   The Incorporated
# 14  tt0116916     movie                                 The Lord Protector
#
#                                 originalTitle  isAdult  startYear  endYear  \
# 0                              Kate & Leopold        0     2001.0      NaN
# 1   El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                  The Other Side of the Wind        0     2018.0      NaN
# 3                           The Naked Monster        0     2005.0      NaN
# 4                        Crime and Punishment        0     2002.0      NaN
# 5                       La Telenovela Errante        0     2017.0      NaN
# 6           Zycie za zycie. Maksymilian Kolbe        0     2006.0      NaN
# 7                  West from North Goes South        0     2004.0      NaN
# 8                             The Fantasticks        0     2000.0      NaN
# 9                               For the Cause        0     2000.0      NaN
# 10                           The Silent Force        0     2001.0      NaN
# 11                                Consequence        0     2000.0      NaN
# 12                                       Gang        0     2000.0      NaN
# 13                           The Incorporated        0     2000.0      NaN
# 14                         The Lord Protector        0     2001.0      NaN
#
#     runtimeMinutes                    genres                   genre_split
# 0              118    Comedy,Fantasy,Romance    [Comedy, Fantasy, Romance]
# 1               70                     Drama                       [Drama]
# 2              122                     Drama                       [Drama]
# 3              100      Comedy,Horror,Sci-Fi      [Comedy, Horror, Sci-Fi]
# 4              126                     Drama                       [Drama]
# 5               80      Comedy,Drama,Fantasy      [Comedy, Drama, Fantasy]
# 6               90           Biography,Drama            [Biography, Drama]
# 7               96            Comedy,Mystery             [Comedy, Mystery]
# 8               86           Musical,Romance            [Musical, Romance]
# 9              100    Action,Adventure,Drama    [Action, Adventure, Drama]
# 10              90                    Action                      [Action]
# 11              91                     Drama                       [Drama]
# 12             167        Action,Crime,Drama        [Action, Crime, Drama]
# 13              86           Action,Thriller            [Action, Thriller]
# 14             101  Action,Adventure,Fantasy  [Action, Adventure, Fantasy]

# %%
exploded_genres = df.explode('genre_split')
exploded_genres
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# ...          ...       ...                                                ...
# 86977  tt9916190     movie                                          Safeguard
# 86977  tt9916190     movie                                          Safeguard
# 86977  tt9916190     movie                                          Safeguard
# 86978  tt9916362     movie                                              Coven
# 86978  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0     2001.0      NaN
# 0                                 Kate & Leopold        0     2001.0      NaN
# 0                                 Kate & Leopold        0     2001.0      NaN
# 1      El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                     The Other Side of the Wind        0     2018.0      NaN
# ...                                          ...      ...        ...      ...
# 86977                                  Safeguard        0     2020.0      NaN
# 86977                                  Safeguard        0     2020.0      NaN
# 86977                                  Safeguard        0     2020.0      NaN
# 86978                                   Akelarre        0     2020.0      NaN
# 86978                                   Akelarre        0     2020.0      NaN
#
#        runtimeMinutes                     genres genre_split
# 0                 118     Comedy,Fantasy,Romance      Comedy
# 0                 118     Comedy,Fantasy,Romance     Fantasy
# 0                 118     Comedy,Fantasy,Romance     Romance
# 1                  70                      Drama       Drama
# 2                 122                      Drama       Drama
# ...               ...                        ...         ...
# 86977              95  Action,Adventure,Thriller      Action
# 86977              95  Action,Adventure,Thriller   Adventure
# 86977              95  Action,Adventure,Thriller    Thriller
# 86978              92              Drama,History       Drama
# 86978              92              Drama,History     History
#
# [162600 rows x 10 columns]

# %%
unique_genres = sorted(exploded_genres['genre_split'].unique())
unique_genres
# Out:
# ['Action',
#  'Adult',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Game-Show',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'News',
#  'Reality-TV',
#  'Romance',
#  'Sci-Fi',
#  'Sport',
#  'Talk-Show',
#  'Thriller',
#  'War',
#  'Western']

# %% [markdown]
# ### Create new titles_genre table

# %%
## Save just tconst and genres_split as new df
title_genres = exploded_genres[['tconst', 'genre_split']].copy()
title_genres.head()
# Out:
#       tconst genre_split
# 0  tt0035423      Comedy
# 0  tt0035423     Fantasy
# 0  tt0035423     Romance
# 1  tt0062336       Drama
# 2  tt0069049       Drama

# %% [markdown]
# ### Genre Mapper

# %%
# Dictionary
genre_ints = range(len(unique_genres))
genre_map = dict(zip(unique_genres, genre_ints))

genre_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Sport': 20,
#  'Talk-Show': 21,
#  'Thriller': 22,
#  'War': 23,
#  'Western': 24}

# %%
genre_id_map = dict(zip(unique_genres, range(len(unique_genres))))
genre_id_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Sport': 20,
#  'Talk-Show': 21,
#  'Thriller': 22,
#  'War': 23,
#  'Western': 24}

# %%
# Make new integer genre_id and drop string genres
df['genre_id'] = df['genre_split'].replace(genre_map)
df.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
# 3                          The Naked Monster        0     2005.0      NaN
# 4                       Crime and Punishment        0     2002.0      NaN
#
#    runtimeMinutes                  genres                 genre_split  \
# 0             118  Comedy,Fantasy,Romance  [Comedy, Fantasy, Romance]
# 1              70                   Drama                     [Drama]
# 2             122                   Drama                     [Drama]
# 3             100    Comedy,Horror,Sci-Fi    [Comedy, Horror, Sci-Fi]
# 4             126                   Drama                     [Drama]
#
#                      genre_id
# 0  [Comedy, Fantasy, Romance]
# 1                     [Drama]
# 2                     [Drama]
# 3    [Comedy, Horror, Sci-Fi]
# 4                     [Drama]

# %%
df = df.drop(columns = 'genre_split')

# %%
df.head(1)
# Out:
#       tconst titleType    primaryTitle   originalTitle  isAdult  startYear  \
# 0  tt0035423     movie  Kate & Leopold  Kate & Leopold        0     2001.0
#
#    endYear  runtimeMinutes                  genres                    genre_id
# 0      NaN             118  Comedy,Fantasy,Romance  [Comedy, Fantasy, Romance]

# %%
genre_lookup = pd.DataFrame({'genre_name': genre_id_map.keys(), 'genre_id':genre_id_map.values()})
genre_lookup.head(20)
# Out:
#     genre_name  genre_id
# 0       Action         0
# 1        Adult         1
# 2    Adventure         2
# 3    Animation         3
# 4    Biography         4
# 5       Comedy         5
# 6        Crime         6
# 7        Drama         7
# 8       Family         8
# 9      Fantasy         9
# 10   Game-Show        10
# 11     History        11
# 12      Horror        12
# 13       Music        13
# 14     Musical        14
# 15     Mystery        15
# 16        News        16
# 17  Reality-TV        17
# 18     Romance        18
# 19      Sci-Fi        19

# %%
genre_lookup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   genre_name  25 non-null     object
#  1   genre_id    25 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 528.0+ bytes

# %% [markdown]
# # SQL Injection

# %% [markdown]
# ## tmdb

# %%
tmdb = pd.read_csv('Data/tmdb_api_data.csv')
tmdb.head()
# Out:
#    Unnamed: 0    imdb_id  adult                     backdrop_path  \
# 0           0          0    NaN                               NaN
# 1           1  tt0035423    0.0  /tJLV3BAlHOgscVOrA99Wnb2gAef.jpg
# 2           2  tt0114447    0.0                               NaN
# 3           3  tt0116916    0.0  /rFpHBidSlhjflmnLu7BZilyKeQR.jpg
# 4           4  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg
#
#   belongs_to_collection      budget  \
# 0                   NaN         NaN
# 1                   NaN  48000000.0
# 2                   NaN         0.0
# 3                   NaN         0.0
# 4                   NaN  22000000.0
#
#                                               genres homepage        id  \
# 0                                                NaN      NaN       NaN
# 1  [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...      NaN   11232.0
# 2  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN  151007.0
# 3  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      NaN   73549.0
# 4  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN   10696.0
#
#   original_language  ...     revenue runtime  \
# 0               NaN  ...         NaN     NaN
# 1                en  ...  76019048.0   118.0
# 2                en  ...         0.0    90.0
# 3                en  ...         0.0   101.0
# 4                en  ...   5271666.0   104.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'French', 'iso_639_1': 'fr',...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline             title video  \
# 0                                                NaN               NaN   NaN
# 1  If they lived in the same century, they'd be p...    Kate & Leopold   0.0
# 2  They left him for dead... They should have fin...  The Silent Force   0.0
# 3                                                NaN     The Dark Mist   0.0
# 4   In music she found her dream, her love, herself.           Glitter   0.0
#
#    vote_average  vote_count certification
# 0           NaN         NaN           NaN
# 1         6.325      1234.0         PG-13
# 2         5.000         3.0           NaN
# 3         3.500         2.0            PG
# 4         4.405       132.0         PG-13
#
# [5 rows x 27 columns]

# %%
tmdb = tmdb.drop(0)
tmdb.head()
# Out:
#    Unnamed: 0    imdb_id  adult                     backdrop_path  \
# 1           1  tt0035423    0.0  /tJLV3BAlHOgscVOrA99Wnb2gAef.jpg
# 2           2  tt0114447    0.0                               NaN
# 3           3  tt0116916    0.0  /rFpHBidSlhjflmnLu7BZilyKeQR.jpg
# 4           4  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg
# 5           5  tt0118652    0.0  /mWxJEFRMvkG4UItYJkRDMgWQ08Y.jpg
#
#   belongs_to_collection      budget  \
# 1                   NaN  48000000.0
# 2                   NaN         0.0
# 3                   NaN         0.0
# 4                   NaN  22000000.0
# 5                   NaN   1000000.0
#
#                                               genres homepage        id  \
# 1  [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...      NaN   11232.0
# 2  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN  151007.0
# 3  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      NaN   73549.0
# 4  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN   10696.0
# 5  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...      NaN   17140.0
#
#   original_language  ...     revenue runtime  \
# 1                en  ...  76019048.0   118.0
# 2                en  ...         0.0    90.0
# 3                en  ...         0.0   101.0
# 4                en  ...   5271666.0   104.0
# 5                en  ...         0.0   100.0
#
#                                     spoken_languages    status  \
# 1  [{'english_name': 'French', 'iso_639_1': 'fr',...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 5  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline                  title  \
# 1  If they lived in the same century, they'd be p...         Kate & Leopold
# 2  They left him for dead... They should have fin...       The Silent Force
# 3                                                NaN          The Dark Mist
# 4   In music she found her dream, her love, herself.                Glitter
# 5  His search for peace of mind... will leave his...  The Attic Expeditions
#
#   video  vote_average  vote_count certification
# 1   0.0         6.325      1234.0         PG-13
# 2   0.0         5.000         3.0           NaN
# 3   0.0         3.500         2.0            PG
# 4   0.0         4.405       132.0         PG-13
# 5   0.0         5.194        31.0             R
#
# [5 rows x 27 columns]

# %%
tmdb = tmdb[['imdb_id','budget', 'revenue', 'certification']]
tmdb.head(1)
# Out:
#      imdb_id      budget     revenue certification
# 1  tt0035423  48000000.0  76019048.0         PG-13

# %%
from sqlalchemy.types import *

key_len = tmdb['imdb_id'].fillna('').map(len).max()
cert_len= tmdb['certification'].fillna('').map(len).max()

df_schema = {
    "imdb_id": CHAR(key_len+1),
    "budget": FLOAT(),
    "revenue": FLOAT(),
    "certification": CHAR(key_len+1)}

# %%
tmdb.to_sql('tmdb_data',conn,dtype=df_schema, if_exists='replace', index=False)
# Out:
# 2644

# %% [markdown]
# ### Confirmation: Queries

# %%
q = """SELECT *
FROM tmdb_data
LIMIT 5;"""
pd.read_sql(q, conn)
# Out:
#      imdb_id      budget     revenue certification
# 0  tt0035423  48000000.0  76019000.0         PG-13
# 1  tt0114447         0.0         0.0          None
# 2  tt0116916         0.0         0.0            PG
# 3  tt0118589  22000000.0   5271670.0         PG-13
# 4  tt0118652   1000000.0         0.0             R

# %%
#Table Information
q = ''' DESC tmdb_data'''
pd.read_sql(q, conn)
# Out:
#            Field      Type Null Key Default Extra
# 0        imdb_id  char(11)  YES        None
# 1         budget     float  YES        None
# 2        revenue     float  YES        None
# 3  certification  char(11)  YES        None

# %%
engine.execute('ALTER TABLE tmdb_data ADD PRIMARY KEY (imdb_id);')

# %% [markdown]
# ## title_genres

# %%
title_genres.to_sql('title_genres', conn, if_exists='replace', index=False)
# Out:
# 162600

# %% [markdown]
# ### Confirmation: Queries

# %%
q = """SELECT *
FROM title_genres
LIMIT 5;"""
pd.read_sql(q, conn)
# Out:
#       tconst genre_split
# 0  tt0035423      Comedy
# 1  tt0035423     Fantasy
# 2  tt0035423     Romance
# 3  tt0062336       Drama
# 4  tt0069049       Drama

# %%
#Table Information
q = ''' DESC title_genres'''
pd.read_sql(q, conn)
# Out:
#          Field  Type Null Key Default Extra
# 0       tconst  text  YES        None
# 1  genre_split  text  YES        None

# %% [markdown]
# ## genres

# %%
genre_lookup.to_sql('genres', conn, if_exists='replace', index=False)
# Out:
# 25

# %% [markdown]
# ### Confirmation: Queries

# %%
q = """SELECT *
FROM genres
LIMIT 5;"""
pd.read_sql(q, conn)
# Out:
#   genre_name  genre_id
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
#Table Information
q = ''' DESC genres'''
pd.read_sql(q, conn)
# Out:
#         Field    Type Null Key Default Extra
# 0  genre_name    text  YES        None
# 1    genre_id  bigint  YES        None
